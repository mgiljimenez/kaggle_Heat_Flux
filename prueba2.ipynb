# %%
import pandas as pd

# %%
data_original=pd.read_csv("data/original_dataset.csv")
data_raw=pd.read_csv("data/data.csv")

# %%
data_original[["author","geometry"]].drop_duplicates()
# Out:
#             author geometry
# 0          Inasaka     tube
# 7           Peskov     tube
# 24        Thompson     tube
# 1226   Weatherhead     tube
# 1388      Williams     tube
# 1439          Beus  annulus
# 1516       Janssen  annulus
# 1798     Mortimore  annulus
# 1817    Kossolapov    plate
# 1829  Richenderfer    plate

# %%
author_geometry={"Inasaka"}

# %%
data_raw[["author","geometry"]].drop_duplicates().dropna()
# Out:
#              author geometry
# 0          Thompson     tube
# 3              Beus  annulus
# 7            Peskov     tube
# 11          Janssen  annulus
# 22      Weatherhead     tube
# 40          Inasaka     tube
# 57         Williams     tube
# 77        Mortimore  annulus
# 108    Richenderfer    plate
# 235      Kossolapov    plate
# 693    Richenderfer     tube
# 809            Beus     tube
# 934       Mortimore     tube
# 2664   Richenderfer  annulus
# 3180         Peskov    plate
# 4476       Thompson    plate
# 5106         Peskov  annulus
# 5399        Janssen     tube
# 6412       Williams    plate
# 7137       Thompson  annulus
# 12514    Kossolapov     tube
# 15910     Mortimore    plate
# 16102       Janssen    plate
# 18026      Williams  annulus
# 23122    Kossolapov  annulus
# 23470       Inasaka    plate
# 26769   Weatherhead  annulus

# %%
data_raw[data_raw["geometry"]=="tube"]
# Out:
#           id       author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 0          0     Thompson     tube            7.00               3770.0
# 1          1     Thompson     tube             NaN               6049.0
# 4          4          NaN     tube           13.79                686.0
# 7          7       Peskov     tube           18.00                750.0
# 8          8          NaN     tube           12.07               4042.0
# ...      ...          ...      ...             ...                  ...
# 31635  31635     Thompson     tube           17.24               2984.0
# 31637  31637  Weatherhead     tube           13.79                688.0
# 31638  31638     Thompson     tube             NaN               3648.0
# 31642  31642     Thompson     tube            6.89               3825.0
# 31643  31643          NaN     tube            6.89               7568.0
#
#        x_e_out [-]  D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31644 entries, 0 to 31643
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   31644 non-null  int64
#  1   author               26620 non-null  object
#  2   geometry             26144 non-null  object
#  3   pressure [MPa]       27192 non-null  float64
#  4   mass_flux [kg/m2-s]  26853 non-null  float64
#  5   x_e_out [-]          21229 non-null  float64
#  6   D_e [mm]             26156 non-null  float64
#  7   D_h [mm]             27055 non-null  float64
#  8   length [mm]          26885 non-null  float64
#  9   chf_exp [MW/m2]      31644 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1865 non-null   int64
#  1   author               1865 non-null   object
#  2   geometry             1865 non-null   object
#  3   pressure [MPa]       1865 non-null   float64
#  4   mass_flux [kg/m2-s]  1865 non-null   int64
#  5   x_e_out [-]          1865 non-null   float64
#  6   D_e [mm]             1865 non-null   float64
#  7   D_h [mm]             1865 non-null   float64
#  8   length [mm]          1865 non-null   int64
#  9   chf_exp [MW/m2]      1865 non-null   float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 145.8+ KB

# %%
data_original[data_original["author"]=="Inasaka"].count()
# Out:
# id                     7
# author                 7
# geometry               7
# pressure [MPa]         7
# mass_flux [kg/m2-s]    7
# x_e_out [-]            7
# D_e [mm]               7
# D_h [mm]               7
# length [mm]            7
# chf_exp [MW/m2]        7
# dtype: int64

# %%
data_raw[data_raw["author"]=="Inasaka"].count()
# Out:
# id                     46
# author                 46
# geometry               35
# pressure [MPa]         42
# mass_flux [kg/m2-s]    39
# x_e_out [-]            28
# D_e [mm]               42
# D_h [mm]               40
# length [mm]            40
# chf_exp [MW/m2]        46
# dtype: int64

# %%
data_raw[data_raw["geometry"]=="plate"][data_raw["pressure [MPa]"]==0.1]
# Out:
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           id        author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 108      108  Richenderfer    plate             0.1               2000.0
# 235      235    Kossolapov    plate             0.1               1277.0
# 417      417    Kossolapov    plate             0.1               1484.0
# 479      479    Kossolapov    plate             0.1               1668.0
# 490      490  Richenderfer    plate             0.1               1000.0
# ...      ...           ...      ...             ...                  ...
# 30823  30823  Richenderfer    plate             0.1               2000.0
# 30854  30854  Richenderfer    plate             0.1                912.0
# 31268  31268           NaN    plate             0.1               2000.0
# ...

# %% [markdown]
# RELLENAMOS TODOS LOS VALORES DE AUTHOR Y GEOMETRY

# %% [markdown]
# ![Texto alternativo](data\tabla_original.png)

# %%
data=data_raw.copy()

#tube, annulus, plate

# %%
# data.loc[data["author"] == "Thompson", "geometry"] = "tube"
# data.loc[data["author"] == "Beus", "geometry"] = "tube"
# data.loc[data["author"] == "Peskov", "geometry"] = "tube"
# data.loc[data["author"] == "Janssen", "geometry"] = "tube"
# data.loc[data["author"] == "Weatherhead", "geometry"] = "tube"
# data.loc[data["author"] == "Inasaka", "geometry"] = "tube"
# data.loc[data["author"] == "Williams", "geometry"] = "tube"
# data.loc[data["author"] == "Mortimore", "geometry"] = "tube"
# data.loc[data["author"] == "Richenderfer", "geometry"] = "tube"
# data.loc[data["author"] == "Kossolapov", "geometry"] = "tube"

# %%
data["author"].unique()
# Out:
# array(['Thompson', 'Beus', nan, 'Peskov', 'Janssen', 'Weatherhead',
#        'Inasaka', 'Williams', 'Mortimore', 'Richenderfer', 'Kossolapov'],
#       dtype=object)

# %%
data[data["geometry"].isnull()].loc[data[data["geometry"].isnull()]["author"] == "Thompson", "geometry"] = "tube"
# Out:
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
