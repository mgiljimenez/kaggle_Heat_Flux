# %%
import pandas as pd
import seaborn as sns

# %%
data_original=pd.read_csv("data/original_dataset.csv")
data_raw=pd.read_csv("data/data.csv")

# %%
sns.heatmap(data_original.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data_raw.corr())
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
name=data_raw.isnull().sum().index
numbers=data_raw.isnull().sum().values

plt.figure(figsize=(10, 6))
plt.bar(name, numbers)
plt.title('Frecuencia de valores faltantes por variable')
plt.xlabel('Variables')
plt.ylabel('Frecuencia de valores faltantes')
plt.xticks(rotation=45)
plt.show()

# %%
data_raw.head()
# Out:
#    id    author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0   0  Thompson     tube            7.00               3770.0       0.1754
# 1   1  Thompson     tube             NaN               6049.0      -0.0416
# 2   2  Thompson      NaN           13.79               2034.0       0.0335
# 3   3      Beus  annulus           13.79               3679.0      -0.0279
# 4   4       NaN     tube           13.79                686.0          NaN
#
#    D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0       NaN      10.8        432.0              3.6
# 1      10.3      10.3        762.0              6.2
# 2       7.7       7.7        457.0              2.5
# 3       5.6      15.2       2134.0              3.0
# 4      11.1      11.1        457.0              2.8

# %%
print(len(data_original))
print(len(data_raw))

31644/1865
# Out:
# 1865
# 31644
# 16.96729222520107

# %%
data_original[["author","geometry"]].drop_duplicates()
# Out:
#             author geometry
# 0          Inasaka     tube
# 7           Peskov     tube
# 24        Thompson     tube
# 1226   Weatherhead     tube
# 1388      Williams     tube
# 1439          Beus  annulus
# 1516       Janssen  annulus
# 1798     Mortimore  annulus
# 1817    Kossolapov    plate
# 1829  Richenderfer    plate

# %%
author_geometry={"Inasaka"}

# %%
data_raw[["author","geometry"]].drop_duplicates().dropna()
# Out:
#              author geometry
# 0          Thompson     tube
# 3              Beus  annulus
# 7            Peskov     tube
# 11          Janssen  annulus
# 22      Weatherhead     tube
# 40          Inasaka     tube
# 57         Williams     tube
# 77        Mortimore  annulus
# 108    Richenderfer    plate
# 235      Kossolapov    plate
# 693    Richenderfer     tube
# 809            Beus     tube
# 934       Mortimore     tube
# 2664   Richenderfer  annulus
# 3180         Peskov    plate
# 4476       Thompson    plate
# 5106         Peskov  annulus
# 5399        Janssen     tube
# 6412       Williams    plate
# 7137       Thompson  annulus
# 12514    Kossolapov     tube
# 15910     Mortimore    plate
# 16102       Janssen    plate
# 18026      Williams  annulus
# 23122    Kossolapov  annulus
# 23470       Inasaka    plate
# 26769   Weatherhead  annulus

# %%
data_raw[data_raw["geometry"]=="tube"]
# Out:
#           id       author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 0          0     Thompson     tube            7.00               3770.0
# 1          1     Thompson     tube             NaN               6049.0
# 4          4          NaN     tube           13.79                686.0
# 7          7       Peskov     tube           18.00                750.0
# 8          8          NaN     tube           12.07               4042.0
# ...      ...          ...      ...             ...                  ...
# 31635  31635     Thompson     tube           17.24               2984.0
# 31637  31637  Weatherhead     tube           13.79                688.0
# 31638  31638     Thompson     tube             NaN               3648.0
# 31642  31642     Thompson     tube            6.89               3825.0
# 31643  31643          NaN     tube            6.89               7568.0
#
#        x_e_out [-]  D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31644 entries, 0 to 31643
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   31644 non-null  int64
#  1   author               26620 non-null  object
#  2   geometry             26144 non-null  object
#  3   pressure [MPa]       27192 non-null  float64
#  4   mass_flux [kg/m2-s]  26853 non-null  float64
#  5   x_e_out [-]          21229 non-null  float64
#  6   D_e [mm]             26156 non-null  float64
#  7   D_h [mm]             27055 non-null  float64
#  8   length [mm]          26885 non-null  float64
#  9   chf_exp [MW/m2]      31644 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1865 non-null   int64
#  1   author               1865 non-null   object
#  2   geometry             1865 non-null   object
#  3   pressure [MPa]       1865 non-null   float64
#  4   mass_flux [kg/m2-s]  1865 non-null   int64
#  5   x_e_out [-]          1865 non-null   float64
#  6   D_e [mm]             1865 non-null   float64
#  7   D_h [mm]             1865 non-null   float64
#  8   length [mm]          1865 non-null   int64
#  9   chf_exp [MW/m2]      1865 non-null   float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 145.8+ KB

# %%
data_original[data_original["author"]=="Inasaka"].count()
# Out:
# id                     7
# author                 7
# geometry               7
# pressure [MPa]         7
# mass_flux [kg/m2-s]    7
# x_e_out [-]            7
# D_e [mm]               7
# D_h [mm]               7
# length [mm]            7
# chf_exp [MW/m2]        7
# dtype: int64

# %%
data_raw[data_raw["author"]=="Inasaka"].count()
# Out:
# id                     46
# author                 46
# geometry               35
# pressure [MPa]         42
# mass_flux [kg/m2-s]    39
# x_e_out [-]            28
# D_e [mm]               42
# D_h [mm]               40
# length [mm]            40
# chf_exp [MW/m2]        46
# dtype: int64

# %%
data_raw[data_raw["geometry"]=="plate"][data_raw["pressure [MPa]"]==0.1]
# Out:
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           id        author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 108      108  Richenderfer    plate             0.1               2000.0
# 235      235    Kossolapov    plate             0.1               1277.0
# 417      417    Kossolapov    plate             0.1               1484.0
# 479      479    Kossolapov    plate             0.1               1668.0
# 490      490  Richenderfer    plate             0.1               1000.0
# ...      ...           ...      ...             ...                  ...
# 30823  30823  Richenderfer    plate             0.1               2000.0
# 30854  30854  Richenderfer    plate             0.1                912.0
# 31268  31268           NaN    plate             0.1               2000.0
# ...

# %% [markdown]
# RELLENAMOS TODOS LOS VALORES DE AUTHOR Y GEOMETRY

# %% [markdown]
# ![Texto alternativo](data\tabla_original.png)

# %%
data=data_raw.copy()

#tube, annulus, plate

# %%
data["author"].unique()
# Out:
# array(['Thompson', 'Beus', nan, 'Peskov', 'Janssen', 'Weatherhead',
#        'Inasaka', 'Williams', 'Mortimore', 'Richenderfer', 'Kossolapov'],
#       dtype=object)

# %%
data[data["author"]=="Richenderfer"][data["geometry"]!="plate"][data["x_e_out [-]"].isnull()]
# Out:
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           id        author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 693      693  Richenderfer     tube            0.10               1500.0
# 1560    1560  Richenderfer      NaN            0.51               1500.0
# 2116    2116  Richenderfer      NaN             NaN               1000.0
# 3734    3734  Richenderfer      NaN            0.20               3861.0
# 4520    4520  Richenderfer  annulus            0.20               1000.0
# 5423    5423  Richenderfer      NaN            0.10               2000.0
# 6200    6200  Richenderfer     tube            0.20               1000.0
# 6526    6526  Richenderfer      NaN            1.01               1000.0
# 6643    6643  Richenderfer      NaN            0.10               1000.0
# ...

# %%
#Todos los inasaka la geometry puede cambiarse por "tube" MENOS ES QUE ES PLATE
#De Peskov cambiar todo menos el que es PLATE

#Thompson se puede cambiar todo por tube
#Weatherhead todo por tube
#Williams no hay ningun error respecto a geometría: todo tube
#Beus cambiar todo a annulus
#Janssen todo annulus
#Mortimore todo annulus
#Kossolapov todo a plate
#Richenderfer todo a plate

# %%
data.loc[data['author'] == 'Thompson', 'geometry'] = 'tube'
data.loc[data['author'] == 'Weatherhead', 'geometry'] = 'tube'
data.loc[data['author'] == 'Williams', 'geometry'] = 'tube'
data.loc[data['author'] == 'Beus', 'geometry'] = 'annulus'
data.loc[data['author'] == 'Janssen', 'geometry'] = 'annulus'
data.loc[data['author'] == 'Mortimore', 'geometry'] = 'annulus'
data.loc[data['author'] == 'Kossolapov', 'geometry'] = 'plate'
data.loc[data['author'] == 'Richenderfer', 'geometry'] = 'plate'

# %%
data[data["author"]=="Richenderfer"][data["pressure [MPa]"]==0.1]
# Out:
# c:\Users\mgilj\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           id        author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 108      108  Richenderfer    plate             0.1               2000.0
# 490      490  Richenderfer    plate             0.1               1000.0
# 693      693  Richenderfer    plate             0.1               1500.0
# 754      754  Richenderfer    plate             0.1                  NaN
# 1120    1120  Richenderfer    plate             0.1               1500.0
# ...      ...           ...      ...             ...                  ...
# 30678  30678  Richenderfer    plate             0.1               1000.0
# 30718  30718  Richenderfer    plate             0.1                310.0
# 30823  30823  Richenderfer    plate             0.1               2000.0
# ...

# %%
## Arreglamos los Annulus
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_h [mm]'] == 15.2), 'author'] = 'Beus'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_h [mm]'] == 13.3), 'author'] = 'Mortimore'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_e [mm]'] == 5.6), 'author'] = 'Beus'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_e [mm]'] == 5), 'author'] = 'Mortimore'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_h [mm]']>11.2), 'author'] = 'Janssen'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_e [mm]']>6), 'author'] = 'Janssen'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['D_e [mm]']==4.6), 'author'] = 'Janssen'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['length [mm]']!=2134), 'author'] = 'Janssen'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['length [mm]']!=2134), 'author'] = 'Janssen'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['mass_flux [kg/m2-s]']==3662), 'author'] = 'Beus'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus') & (data['mass_flux [kg/m2-s]']==1370), 'author'] = 'Mortimore'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'annulus'), 'author'] = 'Beus'

# %%
data[(data["author"].isnull()) & (data["geometry"]=="annulus")]
# Out:
# Empty DataFrame
# Columns: [id, author, geometry, pressure [MPa], mass_flux [kg/m2-s], x_e_out [-], D_e [mm], D_h [mm], length [mm], chf_exp [MW/m2]]
# Index: []

# %%
## Arreglamos los Plate
data.loc[(data['author'].isnull()) & (data['geometry'] == 'plate') & (data['mass_flux [kg/m2-s]'] < 950), 'author'] = 'Kossolapov'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'plate') & (data['pressure [MPa]'] > 0.1), 'author'] = 'Richenderfer'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'plate') & (data['pressure [MPa]'] == 0.1), 'author'] = 'Kossolapov'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'plate') & (data['mass_flux [kg/m2-s]'] > 1300), 'author'] = 'Richenderfer'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'plate'), 'author'] = 'Kossolapov'

# %%
data[(data["geometry"]=="plate")&(data["author"].isnull())]
# Out:
# Empty DataFrame
# Columns: [id, author, geometry, pressure [MPa], mass_flux [kg/m2-s], x_e_out [-], D_e [mm], D_h [mm], length [mm], chf_exp [MW/m2]]
# Index: []

# %%
data[(data["geometry"]=="plate") & (data["author"]=="Kossolapov")]["mass_flux [kg/m2-s]"].mean()
# Out:
# 1038.0564516129032

# %%
data[(data["geometry"]=="plate") & (data["author"]=="Richenderfer")]["mass_flux [kg/m2-s]"].mean()
# Out:
# 1642.701754385965

# %%
## Arreglamos los Tube
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_h [mm]'] ==9.5), 'author'] = 'Williams'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_h [mm]'] ==10), 'author'] = 'Peskov'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_h [mm]'] ==3), 'author'] = 'Inasaka'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_e [mm]'] ==9.5), 'author'] = 'Williams'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_e [mm]'] ==10), 'author'] = 'Peskov'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_e [mm]'] ==3), 'author'] = 'Inasaka'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['length [mm]'] ==1836), 'author'] = 'Williams'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['length [mm]'] ==457), 'author'] = 'Weatherhead'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['length [mm]'] ==100), 'author'] = 'Peskov'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['pressure [MPa]'] ==13.8), 'author'] = 'Weatherhead'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['mass_flux [kg/m2-s]']>6800), 'author'] = 'Thompson'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['mass_flux [kg/m2-s]']<500), 'author'] = 'Weatherhead'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_e [mm]']>11.5), 'author'] = 'Thompson'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['D_h [mm]']>11.5), 'author'] = 'Thompson'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['length [mm]']<380), 'author'] = 'Thompson'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['length [mm]']>1950), 'author'] = 'Thompson'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube') & (data['pressure [MPa]']<0.3), 'author'] = 'Thompson'
data.loc[(data['author'].isnull()) & (data['geometry'] == 'tube'), 'author'] = 'Thompson'

# %%
data[(data["geometry"]=="tube")&(data["author"].isnull())]
# Out:
# Empty DataFrame
# Columns: [id, author, geometry, pressure [MPa], mass_flux [kg/m2-s], x_e_out [-], D_e [mm], D_h [mm], length [mm], chf_exp [MW/m2]]
# Index: []

# %%
## Arreglamos los que son NaN en author y geometry

data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_e [mm]"]==3) ,'author'] = 'Inasaka'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==3) ,'author'] = 'Inasaka'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_e [mm]"]==10) ,'author'] = 'Peskov'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==10) ,'author'] = 'Peskov'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_e [mm]"]==9.5) ,'author'] = 'Williams'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==9.5) ,'author'] = 'Williams'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_e [mm]"]==5.6) ,'author'] = 'Beus'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==15.2) ,'author'] = 'Beus'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_e [mm]"]==5) ,'author'] = 'Mortimore'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==13.3) ,'author'] = 'Mortimore'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==120)&(data["pressure [MPa]"]==0.1) ,'author'] = 'Kossolapov'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["D_h [mm]"]==120)&(data["pressure [MPa]"]!=0.1) ,'author'] = 'Richenderfer'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["length [mm]"]==10) ,'author'] = 'Kossolapov'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["length [mm]"]>2750) ,'author'] = 'Thompson'
data.loc[(data["author"].isnull())&(data["geometry"].isnull())&(data["mass_flux [kg/m2-s]"]>6700) ,'author'] = 'Thompson'
data.loc[(data["author"].isnull())&(data["geometry"].isnull()),'author'] = 'Thompson'

# %%
data.loc[(data["geometry"].isnull())&(data["author"]=="Inasaka"),'geometry'] = 'tube'
data.loc[(data["geometry"].isnull())&(data["author"]=="Peskov"),'geometry'] = 'tube'
data.loc[(data["geometry"].isnull())&(data["author"]=="Thompson"),'geometry'] = 'tube'
data.loc[(data["geometry"].isnull())&(data["author"]=="Weatherhead"),'geometry'] = 'tube'
data.loc[(data["geometry"].isnull())&(data["author"]=="Williams"),'geometry'] = 'tube'
data.loc[(data["geometry"].isnull())&(data["author"]=="Beus"),'geometry'] = 'annulus'
data.loc[(data["geometry"].isnull())&(data["author"]=="Janssen"),'geometry'] = 'annulus'
data.loc[(data["geometry"].isnull())&(data["author"]=="Mortimore"),'geometry'] = 'annulus'
data.loc[(data["geometry"].isnull())&(data["author"]=="Kossolapov"),'geometry'] = 'plate'
data.loc[(data["geometry"].isnull())&(data["author"]=="Richenderfer"),'geometry'] = 'plate'

# %% [markdown]
# Una vez rellenados todos los datos de author y geometry rellenamos todos los demás campos rellenando los vación con la mediana del dataset original segun el autor

# %%
data_original[data_original["author"]=="Inasaka"].describe()
# Out:
#              id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# count  7.000000        7.000000             7.000000     7.000000       7.0
# mean   4.000000        0.548571          5628.571429    -0.096943       3.0
# std    2.160247        0.216905           886.405260     0.037811       0.0
# min    1.000000        0.310000          4300.000000    -0.146000       3.0
# 25%    2.500000        0.360000          5100.000000    -0.122250       3.0
# 50%    4.000000        0.620000          5600.000000    -0.104100       3.0
# 75%    5.500000        0.640000          6300.000000    -0.072250       3.0
# max    7.000000        0.910000          6700.000000    -0.039500       3.0
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# count       7.0          7.0         7.000000
# mean        3.0        100.0        10.971429
# std         0.0          0.0         2.774115
# min         3.0        100.0         7.300000
# 25%         3.0        100.0         9.400000
# ...

# %%
data.loc[(data['author']=="Inasaka") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 0.548571
data.loc[(data['author']=="Inasaka") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 5628.57
data.loc[(data['author']=="Inasaka") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 3
data.loc[(data['author']=="Inasaka") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 3
data.loc[(data['author']=="Inasaka") & (data['length [mm]'].isnull()), 'length [mm]'] = 100

# %%
data_original[data_original["author"]=="Peskov"].describe()
# Out:
#               id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# count  17.000000       17.000000            17.000000    17.000000      17.0
# mean   16.000000       14.235294          2642.705882    -0.028182      10.0
# std     5.049752        3.152963          1483.803759     0.096238       0.0
# min     8.000000       10.000000           750.000000    -0.230600      10.0
# 25%    12.000000       12.000000          1617.000000    -0.068000      10.0
# 50%    16.000000       14.000000          2217.000000    -0.046500      10.0
# 75%    20.000000       16.000000          3861.000000     0.031100      10.0
# max    24.000000       20.000000          5361.000000     0.134400      10.0
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# count      17.0    17.000000        17.000000
# mean       10.0  1009.294118         2.494118
# std         0.0   476.048549         1.190310
# min        10.0   400.000000         0.900000
# ...

# %%
data.loc[(data['author']=="Peskov") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 14.235
data.loc[(data['author']=="Peskov") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 2642.705
data.loc[(data['author']=="Peskov") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 10
data.loc[(data['author']=="Peskov") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 10
data.loc[(data['author']=="Peskov") & (data['length [mm]'].isnull()), 'length [mm]'] = 1009.29

# %%
data_original[data_original["author"]=="Thompson"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count  1202.000000     1202.000000          1202.000000  1202.000000
# mean    625.500000       10.262970          3315.693012     0.004497
# std     347.131819        4.214651          1697.328084     0.118421
# min      25.000000        0.100000           542.000000    -0.866700
# 25%     325.250000        6.890000          2021.000000    -0.059000
# 50%     625.500000       10.510000          3146.000000     0.012900
# 75%     925.750000       13.790000          4069.000000     0.086875
# max    1226.000000       20.680000          7975.000000     0.212000
#
#           D_e [mm]     D_h [mm]  length [mm]  chf_exp [MW/m2]
# count  1202.000000  1202.000000  1202.000000      1202.000000
# mean      9.218636     9.218636   680.588186         4.211398
# std       7.444317     7.444317   530.999958         1.983662
# min       1.000000     1.000000    25.000000         1.000000
# ...

# %%
data.loc[(data['author']=="Thompson") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 10.26
data.loc[(data['author']=="Thompson") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 3315.69
data.loc[(data['author']=="Thompson") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 9.218
data.loc[(data['author']=="Thompson") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 9.218
data.loc[(data['author']=="Thompson") & (data['length [mm]'].isnull()), 'length [mm]'] = 680.588

# %%
data_original[data_original["author"]=="Weatherhead"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count   162.000000    1.620000e+02           162.000000   162.000000
# mean   1307.500000    1.379000e+01          1434.783951    -0.039708
# std      46.909487    5.345595e-15           627.054890     0.140696
# min    1227.000000    1.379000e+01           332.000000    -0.485400
# 25%    1267.250000    1.379000e+01           925.250000    -0.138475
# 50%    1307.500000    1.379000e+01          1370.000000    -0.016850
# 75%    1347.750000    1.379000e+01          1953.000000     0.078600
# max    1388.000000    1.379000e+01          2712.000000     0.193600
#
#          D_e [mm]    D_h [mm]  length [mm]  chf_exp [MW/m2]
# count  162.000000  162.000000        162.0       162.000000
# mean     9.127160    9.127160        457.0         2.937654
# std      1.683166    1.683166          0.0         1.001118
# min      7.700000    7.700000        457.0         1.300000
# ...

# %%
data.loc[(data['author']=="Weatherhead") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 1.379000e+01
data.loc[(data['author']=="Weatherhead") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 1434.78
data.loc[(data['author']=="Weatherhead") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 9.127
data.loc[(data['author']=="Weatherhead") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 9.127
data.loc[(data['author']=="Weatherhead") & (data['length [mm]'].isnull()), 'length [mm]'] = 457

# %%
data_original[data_original["author"]=="Williams"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count    51.000000       51.000000            51.000000    51.000000
# mean   1414.000000       13.140784          2837.313725     0.087967
# std      14.866069        2.264426          1037.392221     0.059460
# min    1389.000000        5.520000           670.000000    -0.027800
# 25%    1401.500000       12.410000          2663.500000     0.042650
# 50%    1414.000000       13.790000          2710.000000     0.097000
# 75%    1426.500000       15.170000          4017.500000     0.147000
# max    1439.000000       15.170000          4684.000000     0.171200
#
#        D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# count      51.0      51.0         51.0        51.000000
# mean        9.5       9.5       1836.0         2.068627
# std         0.0       0.0          0.0         0.754583
# min         9.5       9.5       1836.0         0.900000
# 25%         9.5       9.5       1836.0         1.500000
# ...

# %%
data.loc[(data['author']=="Williams") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 13.14
data.loc[(data['author']=="Williams") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 2837.31
data.loc[(data['author']=="Williams") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 9.5	
data.loc[(data['author']=="Williams") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 9.5	
data.loc[(data['author']=="Williams") & (data['length [mm]'].isnull()), 'length [mm]'] = 1836

# %%
data_original[data_original["author"]=="Beus"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count    77.000000       77.000000            77.000000    77.000000
# mean   1478.000000       12.597143          2310.259740     0.073042
# std      22.371857        2.815653          1005.330496     0.101642
# min    1440.000000        5.520000           671.000000    -0.313700
# 25%    1459.000000       11.030000          1354.000000     0.022400
# 50%    1478.000000       13.790000          2710.000000     0.084700
# 75%    1497.000000       15.510000          2741.000000     0.146100
# max    1516.000000       15.510000          3721.000000     0.232000
#
#            D_e [mm]      D_h [mm]  length [mm]  chf_exp [MW/m2]
# count  7.700000e+01  7.700000e+01         77.0        77.000000
# mean   5.600000e+00  1.520000e+01       2134.0         1.815584
# std    2.682008e-15  5.364016e-15          0.0         0.600672
# min    5.600000e+00  1.520000e+01       2134.0         0.800000
# ...

# %%
data.loc[(data['author']=="Beus") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 12.597
data.loc[(data['author']=="Beus") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 2310.25
data.loc[(data['author']=="Beus") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 5.6	
data.loc[(data['author']=="Beus") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 1.520000e+01
data.loc[(data['author']=="Beus") & (data['length [mm]'].isnull()), 'length [mm]'] = 2134

# %%
data_original[data_original["author"]=="Janssen"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count   282.000000      282.000000           282.000000   282.000000
# mean   1657.500000        7.007660          2173.925532     0.078982
# std      81.550598        1.098683          1295.994705     0.078412
# min    1517.000000        4.130000           381.000000    -0.133200
# 25%    1587.250000        6.890000          1519.000000     0.019625
# 50%    1657.500000        6.890000          1838.000000     0.086550
# 75%    1727.750000        6.920000          2346.000000     0.139600
# max    1798.000000        9.720000          5913.000000     0.213800
#
#          D_e [mm]    D_h [mm]  length [mm]  chf_exp [MW/m2]
# count  282.000000  282.000000   282.000000       282.000000
# mean    10.929078   34.520567  1740.109929         3.295035
# std      3.666042   17.542946   653.858631         0.892222
# min      4.600000   11.300000   737.000000         1.400000
# ...

# %%
data.loc[(data['author']=="Janssen") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 7
data.loc[(data['author']=="Janssen") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 2173.925
data.loc[(data['author']=="Janssen") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 10.929	
data.loc[(data['author']=="Janssen") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 34.52
data.loc[(data['author']=="Janssen") & (data['length [mm]'].isnull()), 'length [mm]'] = 1740.109

# %%
data_original[data_original["author"]=="Mortimore"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count    19.000000       19.000000            19.000000     19.00000
# mean   1808.000000       11.611053          1971.947368      0.08990
# std       5.627314        2.359750           961.874182      0.10165
# min    1799.000000        8.270000           677.000000     -0.12570
# 25%    1803.500000        9.650000          1341.500000      0.05365
# 50%    1808.000000       11.030000          1370.000000      0.10310
# 75%    1812.500000       13.790000          2708.000000      0.16855
# max    1817.000000       13.790000          3637.000000      0.22250
#
#        D_e [mm]      D_h [mm]  length [mm]  chf_exp [MW/m2]
# count      19.0  1.900000e+01         19.0        19.000000
# mean        5.0  1.330000e+01       2134.0         1.652632
# std         0.0  1.825033e-15          0.0         0.450146
# min         5.0  1.330000e+01       2134.0         0.900000
# ...

# %%
data.loc[(data['author']=="Mortimore") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 11.61
data.loc[(data['author']=="Mortimore") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 1971.947
data.loc[(data['author']=="Mortimore") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 5
data.loc[(data['author']=="Mortimore") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 1.330000e+01
data.loc[(data['author']=="Mortimore") & (data['length [mm]'].isnull()), 'length [mm]'] = 2134

# %%
data_original[data_original["author"]=="Kossolapov"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count    12.000000    1.200000e+01            12.000000    12.000000
# mean   1823.500000    1.000000e-01           792.250000    -0.074350
# std       3.605551    1.449488e-17           584.935447     0.047911
# min    1818.000000    1.000000e-01             0.000000    -0.139200
# 25%    1820.750000    1.000000e-01           339.000000    -0.104475
# 50%    1823.500000    1.000000e-01           682.000000    -0.069750
# 75%    1826.250000    1.000000e-01          1003.250000    -0.039625
# max    1829.000000    1.000000e-01          2078.000000    -0.018700
#
#        D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# count      12.0      12.0         12.0        12.000000
# mean       15.0     120.0         10.0         6.841667
# std         0.0       0.0          0.0         4.132237
# min        15.0     120.0         10.0         2.100000
# 25%        15.0     120.0         10.0         3.825000
# ...

# %%
data.loc[(data['author']=="Kossolapov") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 1.000000e-01	
data.loc[(data['author']=="Kossolapov") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 792.25
data.loc[(data['author']=="Kossolapov") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 15
data.loc[(data['author']=="Kossolapov") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 120
data.loc[(data['author']=="Kossolapov") & (data['length [mm]'].isnull()), 'length [mm]'] = 10

# %%
data_original[data_original["author"]=="Richenderfer"].describe()
# Out:
#                 id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count    36.000000       36.000000            36.000000    36.000000
# mean   1847.500000        0.455000          1500.000000    -0.023342
# std      10.535654        0.359321           414.039336     0.012730
# min    1830.000000        0.100000          1000.000000    -0.043400
# 25%    1838.750000        0.175000          1000.000000    -0.037600
# 50%    1847.500000        0.355000          1500.000000    -0.019850
# 75%    1856.250000        0.635000          2000.000000    -0.010725
# max    1865.000000        1.010000          2000.000000    -0.009300
#
#        D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# count      36.0      36.0         36.0        36.000000
# mean       15.0     120.0         10.0         6.769444
# std         0.0       0.0          0.0         2.204129
# min        15.0     120.0         10.0         3.500000
# 25%        15.0     120.0         10.0         5.050000
# ...

# %%
data.loc[(data['author']=="Richenderfer") & (data['pressure [MPa]'].isnull()), 'pressure [MPa]'] = 0.455
data.loc[(data['author']=="Richenderfer") & (data['mass_flux [kg/m2-s]'].isnull()), 'mass_flux [kg/m2-s]'] = 1500
data.loc[(data['author']=="Richenderfer") & (data['D_e [mm]'].isnull()), 'D_e [mm]'] = 15
data.loc[(data['author']=="Richenderfer") & (data['D_h [mm]'].isnull()), 'D_h [mm]'] = 120
data.loc[(data['author']=="Richenderfer") & (data['length [mm]'].isnull()), 'length [mm]'] = 10

# %%
data.to_csv("data/datos_modificados.csv", index=False)
