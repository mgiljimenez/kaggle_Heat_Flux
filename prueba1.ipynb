# %%
import pandas as pd

# %%
data_original=pd.read_csv("data/original_dataset.csv")
data_raw=pd.read_csv("data/data.csv")

# %%
data_raw_complete=data_raw.dropna()
data_raw_complete
# Out:
#           id       author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 3          3         Beus  annulus           13.79               3679.0
# 9          9       Peskov     tube           12.00               1617.0
# 15        15     Thompson     tube           12.07               3255.0
# 17        17     Thompson     tube           10.41               2563.0
# 30        30      Janssen  annulus            9.68               5615.0
# ...      ...          ...      ...             ...                  ...
# 31623  31623      Janssen  annulus            8.27               2731.0
# 31624  31624  Weatherhead     tube           13.79                963.0
# 31626  31626     Thompson     tube           15.51               2984.0
# 31627  31627     Thompson     tube            0.64               3282.0
# 31635  31635     Thompson     tube           17.24               2984.0
#
#        x_e_out [-]  D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...

# %% [markdown]
# Unimos el dataset original a las filas completas que tenemos del dataset generado y entrenamos sobre estos datos
#
# #### Abordamos el problema con pocos datos pero de calidad

# %%
data=pd.concat([data_raw_complete,data_original])
data
# Out:
#         id        author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 3        3          Beus  annulus           13.79               3679.0
# 9        9        Peskov     tube           12.00               1617.0
# 15      15      Thompson     tube           12.07               3255.0
# 17      17      Thompson     tube           10.41               2563.0
# 30      30       Janssen  annulus            9.68               5615.0
# ...    ...           ...      ...             ...                  ...
# 1860  1861  Richenderfer    plate            1.01               1500.0
# 1861  1862  Richenderfer    plate            1.01               1500.0
# 1862  1863  Richenderfer    plate            1.01               2000.0
# 1863  1864  Richenderfer    plate            1.01               2000.0
# 1864  1865  Richenderfer    plate            1.01               2000.0
#
#       x_e_out [-]  D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...
