# %%
import pandas as pd
raw_data=pd.read_csv("data/data.csv")
predict_data = data[pd.isna(data["x_e_out [-]"])]
predict_data=predict_data.drop(columns=["x_e_out [-]"])
data=raw_data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31644 entries, 0 to 31643
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   31644 non-null  int64
#  1   author               26620 non-null  object
#  2   geometry             26144 non-null  object
#  3   pressure [MPa]       27192 non-null  float64
#  4   mass_flux [kg/m2-s]  26853 non-null  float64
#  5   x_e_out [-]          21229 non-null  float64
#  6   D_e [mm]             26156 non-null  float64
#  7   D_h [mm]             27055 non-null  float64
#  8   length [mm]          26885 non-null  float64
#  9   chf_exp [MW/m2]      31644 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
data.head()
# Out:
#    id    author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0   0  Thompson     tube            7.00               3770.0       0.1754
# 1   1  Thompson     tube             NaN               6049.0      -0.0416
# 2   2  Thompson      NaN           13.79               2034.0       0.0335
# 3   3      Beus  annulus           13.79               3679.0      -0.0279
# 4   4       NaN     tube           13.79                686.0          NaN
#
#    D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0       NaN      10.8        432.0              3.6
# 1      10.3      10.3        762.0              6.2
# 2       7.7       7.7        457.0              2.5
# 3       5.6      15.2       2134.0              3.0
# 4      11.1      11.1        457.0              2.8

# %%
print(data["author"].unique())
print(data["geometry"].unique())
author_geometry=data[["author","geometry"]].drop_duplicates().dropna()
author_geometry
# Out:
# ['Thompson' 'Beus' nan 'Peskov' 'Janssen' 'Weatherhead' 'Inasaka'
#  'Williams' 'Mortimore' 'Richenderfer' 'Kossolapov']
# ['tube' nan 'annulus' 'plate']
#              author geometry
# 0          Thompson     tube
# 3              Beus  annulus
# 7            Peskov     tube
# 11          Janssen  annulus
# 22      Weatherhead     tube
# 40          Inasaka     tube
# 57         Williams     tube
# 77        Mortimore  annulus
# 108    Richenderfer    plate
# 235      Kossolapov    plate
# 693    Richenderfer     tube
# 809            Beus     tube
# 934       Mortimore     tube
# 2664   Richenderfer  annulus
# 3180         Peskov    plate
# 4476       Thompson    plate
# 5106         Peskov  annulus
# 5399        Janssen     tube
# 6412       Williams    plate
# 7137       Thompson  annulus
# 12514    Kossolapov     tube
# 15910     Mortimore    plate
# 16102       Janssen    plate
# 18026      Williams  annulus
# 23122    Kossolapov  annulus
# 23470       Inasaka    plate
# ...

# %%
dic_autor_geometry = {}
for _, row in author_geometry.iterrows():
    autor = row['author']
    geometry = row['geometry']
    if autor in dic_autor_geometry:
        dic_autor_geometry[autor].append(geometry)
    else:
        dic_autor_geometry[autor] = [geometry]

# Imprimir el diccionario
print(dic_autor_geometry)
# Out:
# {'Thompson': ['tube', 'plate', 'annulus'], 'Beus': ['annulus', 'tube'], 'Peskov': ['tube', 'plate', 'annulus'], 'Janssen': ['annulus', 'tube', 'plate'], 'Weatherhead': ['tube', 'annulus'], 'Inasaka': ['tube', 'plate'], 'Williams': ['tube', 'plate', 'annulus'], 'Mortimore': ['annulus', 'tube', 'plate'], 'Richenderfer': ['plate', 'tube', 'annulus'], 'Kossolapov': ['plate', 'tube', 'annulus']}

# %%
for autor in dic_autor_geometry:
    for geometria in dic_autor_geometry[autor]:
        print(autor, geometria)
        print(data[data["author"]==autor][data["geometry"]==geometria].describe())
# Out:
# Thompson tube
#                  id  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# count  14324.000000    12393.000000         12180.000000   9555.00000
# mean   15877.367565       10.660803          3496.055583     -0.01384
# std     9158.588745        4.276420          1838.097515      0.10361
# min        0.000000        0.100000             0.000000     -0.86670
# 25%     7915.000000        6.890000          1980.000000     -0.05940
# 50%    15914.500000       11.030000          3662.000000     -0.00780
# 75%    23791.250000       13.790000          4136.000000      0.05330
# max    31642.000000       20.680000          7975.000000      0.21200
#
#            D_e [mm]      D_h [mm]   length [mm]  chf_exp [MW/m2]
# count  11831.000000  12270.000000  12229.000000     14324.000000
# mean       8.210692      8.270326    609.942595         4.138362
# std        5.883229      6.116300    464.029507         2.000802
# ...

# %% [markdown]
# Relaciones encontradas
#
# Mortimore annulus
#     length [mm]=2134
#
#
# Mortimore tube
#     length [mm]=2134.0
#
#
# Richenderfer tube
#     D_e [mm]=15
#     D_h [mm]=120
#
#
#
# Richenderfer annulus
#     D_e [mm] = 15
#     D_h [mm]=120
#     length [mm]=10
#
#
# Kossolapov tube
#     D_e [mm]=15
#     D_h [mm]=120
#     length [mm]=10

# %%
data["author"].unique()
# Out:
# array(['Thompson', 'Beus', nan, 'Peskov', 'Janssen', 'Weatherhead',
#        'Inasaka', 'Williams', 'Mortimore', 'Richenderfer', 'Kossolapov'],
#       dtype=object)

# %%
original_data=pd.read_csv("data/original_dataset.csv")

# %%
original_data.head()
# Out:
#    id   author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0   1  Inasaka     tube            0.39                 5600      -0.1041
# 1   2  Inasaka     tube            0.31                 6700      -0.0596
# 2   3  Inasaka     tube            0.33                 4300      -0.0395
# 3   4  Inasaka     tube            0.62                 6400      -0.1460
# 4   5  Inasaka     tube            0.64                 4700      -0.0849
#
#    D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0       3.0       3.0          100             11.3
# 1       3.0       3.0          100             10.6
# 2       3.0       3.0          100              7.3
# 3       3.0       3.0          100             12.8
# 4       3.0       3.0          100             11.0

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1865 non-null   int64
#  1   author               1865 non-null   object
#  2   geometry             1865 non-null   object
#  3   pressure [MPa]       1865 non-null   float64
#  4   mass_flux [kg/m2-s]  1865 non-null   int64
#  5   x_e_out [-]          1865 non-null   float64
#  6   D_e [mm]             1865 non-null   float64
#  7   D_h [mm]             1865 non-null   float64
#  8   length [mm]          1865 non-null   int64
#  9   chf_exp [MW/m2]      1865 non-null   float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 145.8+ KB

# %%
original_data[["author","geometry"]].drop_duplicates()
# Out:
#             author geometry
# 0          Inasaka     tube
# 7           Peskov     tube
# 24        Thompson     tube
# 1226   Weatherhead     tube
# 1388      Williams     tube
# 1439          Beus  annulus
# 1516       Janssen  annulus
# 1798     Mortimore  annulus
# 1817    Kossolapov    plate
# 1829  Richenderfer    plate

# %%
original_data[original_data["author"]=="Inasaka"]
# Out:
#    id   author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0   1  Inasaka     tube            0.39                 5600      -0.1041
# 1   2  Inasaka     tube            0.31                 6700      -0.0596
# 2   3  Inasaka     tube            0.33                 4300      -0.0395
# 3   4  Inasaka     tube            0.62                 6400      -0.1460
# 4   5  Inasaka     tube            0.64                 4700      -0.0849
# 5   6  Inasaka     tube            0.64                 6200      -0.1221
# 6   7  Inasaka     tube            0.91                 5500      -0.1224
#
#    D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0       3.0       3.0          100             11.3
# 1       3.0       3.0          100             10.6
# 2       3.0       3.0          100              7.3
# 3       3.0       3.0          100             12.8
# 4       3.0       3.0          100             11.0
# 5       3.0       3.0          100              8.2
# ...

# %%
data[data["author"]=="Inasaka"]
# Out:
#           id   author geometry  pressure [MPa]  mass_flux [kg/m2-s]  \
# 40        40  Inasaka     tube           12.07               6200.0
# 530      530  Inasaka     tube            0.64               6700.0
# 1100    1100  Inasaka     tube            0.39                  NaN
# 1610    1610  Inasaka      NaN            0.64               6700.0
# 1731    1731  Inasaka      NaN            0.33                  NaN
# 2644    2644  Inasaka      NaN            0.91               6700.0
# 4293    4293  Inasaka     tube            0.33               4300.0
# 6391    6391  Inasaka     tube            0.62               6200.0
# 6550    6550  Inasaka     tube            0.91               4700.0
# 6729    6729  Inasaka     tube            0.91                  NaN
# 6888    6888  Inasaka     tube             NaN               5500.0
# 8093    8093  Inasaka     tube           18.27                842.0
# 8513    8513  Inasaka     tube             NaN                  NaN
# ...

# %%
author_geometry.drop_duplicates()
# Out:
#              author geometry
# 0          Thompson     tube
# 3              Beus  annulus
# 7            Peskov     tube
# 11          Janssen  annulus
# 22      Weatherhead     tube
# 40          Inasaka     tube
# 57         Williams     tube
# 77        Mortimore  annulus
# 108    Richenderfer    plate
# 235      Kossolapov    plate
# 693    Richenderfer     tube
# 809            Beus     tube
# 934       Mortimore     tube
# 2664   Richenderfer  annulus
# 3180         Peskov    plate
# 4476       Thompson    plate
# 5106         Peskov  annulus
# 5399        Janssen     tube
# 6412       Williams    plate
# 7137       Thompson  annulus
# 12514    Kossolapov     tube
# 15910     Mortimore    plate
# 16102       Janssen    plate
# 18026      Williams  annulus
# 23122    Kossolapov  annulus
# 23470       Inasaka    plate
# 26769   Weatherhead  annulus

# %%
original_data["geometry"].unique()
# Out:
# array(['tube', 'annulus', 'plate'], dtype=object)
